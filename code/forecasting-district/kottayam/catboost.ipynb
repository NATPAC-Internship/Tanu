# %%
import folium
import pandas as pd

df=pd.read_csv("./../../../dataset/prediction/CatBoo_chumma.csv")
kollam_df = df[df['District'] == "Kottayam"]

# %%
#2024 plotting
columns_to_drop = ['2025', '2026', '2027', '2028']
filtered_2024_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2024_df['Latitude'].mean()
mean_longitude = filtered_2024_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2024_df.iterrows():
    
    amount = row['2024']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2024_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f21f9ebc1612d25fda5c36e16a10ab21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f21f9ebc1612d25fda5c36e16a10ab21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f21f9ebc1612d25fda5c36e16a10ab21 = L.map(
#                 &quot;map_f21f9ebc1612d25fda5c36e16a10ab21&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d23c205203c85ff3c503eb4fc6a715c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d23c205203c85ff3c503eb4fc6a715c2.addTo(map_f21f9ebc1612d25fda5c36e16a10ab21);
#
#
#             var circle_marker_1c074a1f4d09f3b259d7bbf21477492a = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f21f9ebc1612d25fda5c36e16a10ab21);
#
#
#         var popup_0a33da6ff281e25f2c73aaa480c98bb3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04433184acf3ec086538d3ff911e7dbc = $(`&lt;div id=&quot;html_04433184acf3ec086538d3ff911e7dbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_0a33da6ff281e25f2c73aaa480c98bb3.setContent(html_04433184acf3ec086538d3ff911e7dbc);
#
#
#
#         circle_marker_1c074a1f4d09f3b259d7bbf21477492a.bindPopup(popup_0a33da6ff281e25f2c73aaa480c98bb3)
#         ;
#
#
#
#
#             var circle_marker_95b4db26451e9e195d3c6eaa5ac9d8b1 = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f21f9ebc1612d25fda5c36e16a10ab21);
#
#
#         var popup_08d0b293fc7d42dd13dce918046511f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78a0c8adc5aa72d5f04902f946ceab0a = $(`&lt;div id=&quot;html_78a0c8adc5aa72d5f04902f946ceab0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 476.8222361086519&lt;/div&gt;`)[0];
#                 popup_08d0b293fc7d42dd13dce918046511f3.setContent(html_78a0c8adc5aa72d5f04902f946ceab0a);
#
#
#
#         circle_marker_95b4db26451e9e195d3c6eaa5ac9d8b1.bindPopup(popup_08d0b293fc7d42dd13dce918046511f3)
#         ;
#
#
#
#
#             var circle_marker_590ddfccafce8579f523524f26a4f63e = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f21f9ebc1612d25fda5c36e16a10ab21);
#
#
#         var popup_9a2746242f5dcf7cb469a238e46a23ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d40266b2658b6bc271775516e9c24a24 = $(`&lt;div id=&quot;html_d40266b2658b6bc271775516e9c24a24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_9a2746242f5dcf7cb469a238e46a23ee.setContent(html_d40266b2658b6bc271775516e9c24a24);
#
#
#
#         circle_marker_590ddfccafce8579f523524f26a4f63e.bindPopup(popup_9a2746242f5dcf7cb469a238e46a23ee)
#         ;
#
#
#
#
#             var circle_marker_844724ab3abdc18d39ddc2aad684f7fb = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray

# %%
#2025 plotting
columns_to_drop = ['2024', '2026', '2027', '2028']
filtered_2025_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2025_df['Latitude'].mean()
mean_longitude = filtered_2025_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2025_df.iterrows():
    
    amount = row['2025']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2025_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d70a0803bbc37d681fca2226b928bf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d70a0803bbc37d681fca2226b928bf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d70a0803bbc37d681fca2226b928bf0 = L.map(
#                 &quot;map_6d70a0803bbc37d681fca2226b928bf0&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5bef713ecbe2575f3e67afd553af81f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5bef713ecbe2575f3e67afd553af81f6.addTo(map_6d70a0803bbc37d681fca2226b928bf0);
#
#
#             var circle_marker_e4b2736f48216d5460c4e4f9cb609870 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d70a0803bbc37d681fca2226b928bf0);
#
#
#         var popup_4946295b47fdb063f26b7412f2ef5871 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6487091670589db9dfc3e5767707a0cf = $(`&lt;div id=&quot;html_6487091670589db9dfc3e5767707a0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_4946295b47fdb063f26b7412f2ef5871.setContent(html_6487091670589db9dfc3e5767707a0cf);
#
#
#
#         circle_marker_e4b2736f48216d5460c4e4f9cb609870.bindPopup(popup_4946295b47fdb063f26b7412f2ef5871)
#         ;
#
#
#
#
#             var circle_marker_a805c1389fd46aabe043e54263c4f002 = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d70a0803bbc37d681fca2226b928bf0);
#
#
#         var popup_43d1f06bc7e8c1de0bca3d84827217b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0cd1efd5dee3c2ea9b55a5d675e222f0 = $(`&lt;div id=&quot;html_0cd1efd5dee3c2ea9b55a5d675e222f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_43d1f06bc7e8c1de0bca3d84827217b5.setContent(html_0cd1efd5dee3c2ea9b55a5d675e222f0);
#
#
#
#         circle_marker_a805c1389fd46aabe043e54263c4f002.bindPopup(popup_43d1f06bc7e8c1de0bca3d84827217b5)
#         ;
#
#
#
#
#             var circle_marker_176bb252e88e73f2d7380875171d3b8f = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d70a0803bbc37d681fca2226b928bf0);
#
#
#         var popup_c567c94aa4f4c872fcab539d8601f68b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59ade8a686d29cd9e6799fb65c4b2796 = $(`&lt;div id=&quot;html_59ade8a686d29cd9e6799fb65c4b2796&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 93.24344789027236&lt;/div&gt;`)[0];
#                 popup_c567c94aa4f4c872fcab539d8601f68b.setContent(html_59ade8a686d29cd9e6799fb65c4b2796);
#
#
#
#         circle_marker_176bb252e88e73f2d7380875171d3b8f.bindPopup(popup_c567c94aa4f4c872fcab539d8601f68b)
#         ;
#
#
#
#
#             var circle_marker_9f0da3ead747dd26be9c9e014f5f6ed3 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray

# %%
#2026 plotting
columns_to_drop = ['2024', '2025', '2027', '2028']
filtered_2026_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2026_df['Latitude'].mean()
mean_longitude = filtered_2026_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2026_df.iterrows():
    
    amount = row['2026']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2026_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7bab84ee9b8f7bf693d5a251f64820f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7bab84ee9b8f7bf693d5a251f64820f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7bab84ee9b8f7bf693d5a251f64820f = L.map(
#                 &quot;map_c7bab84ee9b8f7bf693d5a251f64820f&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4901f7971efaa3ef00d7c863701ee116 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4901f7971efaa3ef00d7c863701ee116.addTo(map_c7bab84ee9b8f7bf693d5a251f64820f);
#
#
#             var circle_marker_bb30cef7ec608647c386b93ccbb3f2c9 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c7bab84ee9b8f7bf693d5a251f64820f);
#
#
#         var popup_edba67cb4da2c375e1b7c759efd41f43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd5380563feff0fd2381d2c020538340 = $(`&lt;div id=&quot;html_bd5380563feff0fd2381d2c020538340&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 4339.947957813885&lt;/div&gt;`)[0];
#                 popup_edba67cb4da2c375e1b7c759efd41f43.setContent(html_bd5380563feff0fd2381d2c020538340);
#
#
#
#         circle_marker_bb30cef7ec608647c386b93ccbb3f2c9.bindPopup(popup_edba67cb4da2c375e1b7c759efd41f43)
#         ;
#
#
#
#
#             var circle_marker_64b8b4a58b061a92dca889cee468c088 = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c7bab84ee9b8f7bf693d5a251f64820f);
#
#
#         var popup_0fda21dea42f1c4648a802b3c0a8a082 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb42ebca70f0b668f99c2b4d2e446cbb = $(`&lt;div id=&quot;html_eb42ebca70f0b668f99c2b4d2e446cbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 29.898836178152123&lt;/div&gt;`)[0];
#                 popup_0fda21dea42f1c4648a802b3c0a8a082.setContent(html_eb42ebca70f0b668f99c2b4d2e446cbb);
#
#
#
#         circle_marker_64b8b4a58b061a92dca889cee468c088.bindPopup(popup_0fda21dea42f1c4648a802b3c0a8a082)
#         ;
#
#
#
#
#             var circle_marker_e190840e0ade870429d8186d8ebbc54b = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c7bab84ee9b8f7bf693d5a251f64820f);
#
#
#         var popup_abffa94fed6a335b9eed7ffc7a8ba26c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cca29317f563708bdd797b88f90d7684 = $(`&lt;div id=&quot;html_cca29317f563708bdd797b88f90d7684&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 421.8043150091253&lt;/div&gt;`)[0];
#                 popup_abffa94fed6a335b9eed7ffc7a8ba26c.setContent(html_cca29317f563708bdd797b88f90d7684);
#
#
#
#         circle_marker_e190840e0ade870429d8186d8ebbc54b.bindPopup(popup_abffa94fed6a335b9eed7ffc7a8ba26c)
#         ;
#
#
#
#
#             var circle_marker_3ef50cf98ad4c01c3c2b887269c7c902 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;

# %%
#2026 plotting
columns_to_drop = ['2024', '2025', '2026', '2028']
filtered_2027_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2027_df['Latitude'].mean()
mean_longitude = filtered_2027_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2027_df.iterrows():
    
    amount = row['2027']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2027_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b00e26e59825e7620de1d489104bf809 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b00e26e59825e7620de1d489104bf809&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b00e26e59825e7620de1d489104bf809 = L.map(
#                 &quot;map_b00e26e59825e7620de1d489104bf809&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9aafe4f448ace35623a2e115b626c157 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9aafe4f448ace35623a2e115b626c157.addTo(map_b00e26e59825e7620de1d489104bf809);
#
#
#             var circle_marker_47a8dbbb04090fff9d18d75d36e3dc07 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b00e26e59825e7620de1d489104bf809);
#
#
#         var popup_8416569c272479ecabe392f3341011aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b31554d3c3cb7d2be97671fe253e4e0d = $(`&lt;div id=&quot;html_b31554d3c3cb7d2be97671fe253e4e0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 2014.3977803716552&lt;/div&gt;`)[0];
#                 popup_8416569c272479ecabe392f3341011aa.setContent(html_b31554d3c3cb7d2be97671fe253e4e0d);
#
#
#
#         circle_marker_47a8dbbb04090fff9d18d75d36e3dc07.bindPopup(popup_8416569c272479ecabe392f3341011aa)
#         ;
#
#
#
#
#             var circle_marker_dab8aef9c860167dbb733140bb69687d = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b00e26e59825e7620de1d489104bf809);
#
#
#         var popup_7d8a7388a51d2002b1cdc09d31f3d814 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_55a7cd301c6a574242136b9acdddd890 = $(`&lt;div id=&quot;html_55a7cd301c6a574242136b9acdddd890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_7d8a7388a51d2002b1cdc09d31f3d814.setContent(html_55a7cd301c6a574242136b9acdddd890);
#
#
#
#         circle_marker_dab8aef9c860167dbb733140bb69687d.bindPopup(popup_7d8a7388a51d2002b1cdc09d31f3d814)
#         ;
#
#
#
#
#             var circle_marker_616c1b5112db18d24bc044ec50b6cf24 = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b00e26e59825e7620de1d489104bf809);
#
#
#         var popup_6a9fe4b4fa6a91b8b38832c35492e963 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f9962785276ff247f01888881be3cec = $(`&lt;div id=&quot;html_2f9962785276ff247f01888881be3cec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 992.6509895864584&lt;/div&gt;`)[0];
#                 popup_6a9fe4b4fa6a91b8b38832c35492e963.setContent(html_2f9962785276ff247f01888881be3cec);
#
#
#
#         circle_marker_616c1b5112db18d24bc044ec50b6cf24.bindPopup(popup_6a9fe4b4fa6a91b8b38832c35492e963)
#         ;
#
#
#
#
#             var circle_marker_8910a11f3150ac30d4b8f35dfb2d4b85 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;,

# %%
#2028 plotting
columns_to_drop = ['2024', '2025', '2026', '2027']
filtered_2028_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2028_df['Latitude'].mean()
mean_longitude = filtered_2028_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2028_df.iterrows():
    
    amount = row['2028']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2028_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d55d6b14bc134e50a50f8072117b55e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d55d6b14bc134e50a50f8072117b55e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d55d6b14bc134e50a50f8072117b55e1 = L.map(
#                 &quot;map_d55d6b14bc134e50a50f8072117b55e1&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81ca4843441d883da10cf63f48ee107c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_81ca4843441d883da10cf63f48ee107c.addTo(map_d55d6b14bc134e50a50f8072117b55e1);
#
#
#             var circle_marker_7fd2beba1b1504416c2c9d5aee10786b = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d55d6b14bc134e50a50f8072117b55e1);
#
#
#         var popup_5ea2a23723fe694549438d32e5dfc2d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77e1f4a486573bd97886fec932572659 = $(`&lt;div id=&quot;html_77e1f4a486573bd97886fec932572659&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 1017.5471402253316&lt;/div&gt;`)[0];
#                 popup_5ea2a23723fe694549438d32e5dfc2d1.setContent(html_77e1f4a486573bd97886fec932572659);
#
#
#
#         circle_marker_7fd2beba1b1504416c2c9d5aee10786b.bindPopup(popup_5ea2a23723fe694549438d32e5dfc2d1)
#         ;
#
#
#
#
#             var circle_marker_68330e0dc43a8fe475d241092ec3f13c = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d55d6b14bc134e50a50f8072117b55e1);
#
#
#         var popup_4d6980f02fcef64f1b28a00d3fe6e1bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e248121764fec02080890831339490f = $(`&lt;div id=&quot;html_0e248121764fec02080890831339490f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 817.3033714552585&lt;/div&gt;`)[0];
#                 popup_4d6980f02fcef64f1b28a00d3fe6e1bf.setContent(html_0e248121764fec02080890831339490f);
#
#
#
#         circle_marker_68330e0dc43a8fe475d241092ec3f13c.bindPopup(popup_4d6980f02fcef64f1b28a00d3fe6e1bf)
#         ;
#
#
#
#
#             var circle_marker_dbcfd26203835b80594ceec51561265e = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d55d6b14bc134e50a50f8072117b55e1);
#
#
#         var popup_29423ff7c512572f822fe91f4d522287 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c426091166f8010d21c2e400f9cbbec = $(`&lt;div id=&quot;html_2c426091166f8010d21c2e400f9cbbec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_29423ff7c512572f822fe91f4d522287.setContent(html_2c426091166f8010d21c2e400f9cbbec);
#
#
#
#         circle_marker_dbcfd26203835b80594ceec51561265e.bindPopup(popup_29423ff7c512572f822fe91f4d522287)
#         ;
#
#
#
#
#             var circle_marker_c3a499f8f51296e36ea9a62110926daa = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;,
