# %%
import folium
import pandas as pd

df=pd.read_csv("./../../../dataset/prediction/Linear_chumma.csv")
kollam_df = df[df['District'] == "Kottayam"]

# %%
#2024 plotting
columns_to_drop = ['2025', '2026', '2027', '2028']
filtered_2024_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2024_df['Latitude'].mean()
mean_longitude = filtered_2024_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2024_df.iterrows():
    
    amount = row['2024']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2024_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34918de32afed971865e59a8d2ed61bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34918de32afed971865e59a8d2ed61bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34918de32afed971865e59a8d2ed61bf = L.map(
#                 &quot;map_34918de32afed971865e59a8d2ed61bf&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6989ea927cee3459706fcce2fd5d323 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c6989ea927cee3459706fcce2fd5d323.addTo(map_34918de32afed971865e59a8d2ed61bf);
#
#
#             var circle_marker_227c4ab0a2be6e9a09154ec9fb864dad = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_34918de32afed971865e59a8d2ed61bf);
#
#
#         var popup_ec8e9c7dafd465c29d2486402e4fff13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5806fd0b6e65d3847322716b111fc77f = $(`&lt;div id=&quot;html_5806fd0b6e65d3847322716b111fc77f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_ec8e9c7dafd465c29d2486402e4fff13.setContent(html_5806fd0b6e65d3847322716b111fc77f);
#
#
#
#         circle_marker_227c4ab0a2be6e9a09154ec9fb864dad.bindPopup(popup_ec8e9c7dafd465c29d2486402e4fff13)
#         ;
#
#
#
#
#             var circle_marker_af1da441054cce22b5228520a5dbd717 = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_34918de32afed971865e59a8d2ed61bf);
#
#
#         var popup_1a13bfb61303019d17318e09bed1506b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_810e6811bbead8224e0a92f51ec14ff4 = $(`&lt;div id=&quot;html_810e6811bbead8224e0a92f51ec14ff4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_1a13bfb61303019d17318e09bed1506b.setContent(html_810e6811bbead8224e0a92f51ec14ff4);
#
#
#
#         circle_marker_af1da441054cce22b5228520a5dbd717.bindPopup(popup_1a13bfb61303019d17318e09bed1506b)
#         ;
#
#
#
#
#             var circle_marker_4ec74fefb7ff0d12dcef1f65cf013b8e = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_34918de32afed971865e59a8d2ed61bf);
#
#
#         var popup_8b312bbdffe7845fefb61b47734cd01a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34441eb65428b4a8052482960afc156d = $(`&lt;div id=&quot;html_34441eb65428b4a8052482960afc156d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_8b312bbdffe7845fefb61b47734cd01a.setContent(html_34441eb65428b4a8052482960afc156d);
#
#
#
#         circle_marker_4ec74fefb7ff0d12dcef1f65cf013b8e.bindPopup(popup_8b312bbdffe7845fefb61b47734cd01a)
#         ;
#
#
#
#
#             var circle_marker_02f2e006252500904ad3d6029f788ccc = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null,

# %%
#2025 plotting
columns_to_drop = ['2024', '2026', '2027', '2028']
filtered_2025_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2025_df['Latitude'].mean()
mean_longitude = filtered_2025_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2025_df.iterrows():
    
    amount = row['2025']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2025_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7e1535cd70c912a74f1db65cadab629 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7e1535cd70c912a74f1db65cadab629&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7e1535cd70c912a74f1db65cadab629 = L.map(
#                 &quot;map_d7e1535cd70c912a74f1db65cadab629&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8060ca37fab4fbebf5c629d2712a7b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e8060ca37fab4fbebf5c629d2712a7b9.addTo(map_d7e1535cd70c912a74f1db65cadab629);
#
#
#             var circle_marker_b01fe8d509c2a274cc3e8f51eab042fb = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d7e1535cd70c912a74f1db65cadab629);
#
#
#         var popup_85bb218761bd456330fe4f7c1afeb9c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9fb434728611ee8ae2700b6cefdfd059 = $(`&lt;div id=&quot;html_9fb434728611ee8ae2700b6cefdfd059&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_85bb218761bd456330fe4f7c1afeb9c9.setContent(html_9fb434728611ee8ae2700b6cefdfd059);
#
#
#
#         circle_marker_b01fe8d509c2a274cc3e8f51eab042fb.bindPopup(popup_85bb218761bd456330fe4f7c1afeb9c9)
#         ;
#
#
#
#
#             var circle_marker_455dd30b63a8dd85270abcd60b7f518b = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d7e1535cd70c912a74f1db65cadab629);
#
#
#         var popup_ef61bd9acaf08d27b1bbad1877e6a28f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86b8112896173b5b9fd718f04ec6da66 = $(`&lt;div id=&quot;html_86b8112896173b5b9fd718f04ec6da66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 8.654405480745659e-11&lt;/div&gt;`)[0];
#                 popup_ef61bd9acaf08d27b1bbad1877e6a28f.setContent(html_86b8112896173b5b9fd718f04ec6da66);
#
#
#
#         circle_marker_455dd30b63a8dd85270abcd60b7f518b.bindPopup(popup_ef61bd9acaf08d27b1bbad1877e6a28f)
#         ;
#
#
#
#
#             var circle_marker_f0f92a6dc7d6dc64bf4153d17b2a9a19 = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d7e1535cd70c912a74f1db65cadab629);
#
#
#         var popup_2a24f959782eaf66a01485af7b6e1fe8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef016987cc99fb211e248f376e62f203 = $(`&lt;div id=&quot;html_ef016987cc99fb211e248f376e62f203&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 8.295655501162569e-11&lt;/div&gt;`)[0];
#                 popup_2a24f959782eaf66a01485af7b6e1fe8.setContent(html_ef016987cc99fb211e248f376e62f203);
#
#
#
#         circle_marker_f0f92a6dc7d6dc64bf4153d17b2a9a19.bindPopup(popup_2a24f959782eaf66a01485af7b6e1fe8)
#         ;
#
#
#
#
#             var circle_marker_15069714affbea2610cc1bc6c0500dc5 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&

# %%
#2026 plotting
columns_to_drop = ['2024', '2025', '2027', '2028']
filtered_2026_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2026_df['Latitude'].mean()
mean_longitude = filtered_2026_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2026_df.iterrows():
    
    amount = row['2026']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2026_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d35293d8db3163a887b472eb9a38b55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d35293d8db3163a887b472eb9a38b55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d35293d8db3163a887b472eb9a38b55 = L.map(
#                 &quot;map_2d35293d8db3163a887b472eb9a38b55&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_189ebb68218aaea3cc995d8bbddbebe3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_189ebb68218aaea3cc995d8bbddbebe3.addTo(map_2d35293d8db3163a887b472eb9a38b55);
#
#
#             var circle_marker_aef59438f8287ec4bb5b64abab46e861 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2d35293d8db3163a887b472eb9a38b55);
#
#
#         var popup_d9fbabb784cbb78698ffa7ce14c5b300 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17adbd9bed630d6df8690647998b0eda = $(`&lt;div id=&quot;html_17adbd9bed630d6df8690647998b0eda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_d9fbabb784cbb78698ffa7ce14c5b300.setContent(html_17adbd9bed630d6df8690647998b0eda);
#
#
#
#         circle_marker_aef59438f8287ec4bb5b64abab46e861.bindPopup(popup_d9fbabb784cbb78698ffa7ce14c5b300)
#         ;
#
#
#
#
#             var circle_marker_10716fe653b4c8242655036e8dd87094 = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2d35293d8db3163a887b472eb9a38b55);
#
#
#         var popup_b9ad3c91e9cb97a03b66f1f584d71dd7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98d426a412a683c31ad45f3781619d33 = $(`&lt;div id=&quot;html_98d426a412a683c31ad45f3781619d33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_b9ad3c91e9cb97a03b66f1f584d71dd7.setContent(html_98d426a412a683c31ad45f3781619d33);
#
#
#
#         circle_marker_10716fe653b4c8242655036e8dd87094.bindPopup(popup_b9ad3c91e9cb97a03b66f1f584d71dd7)
#         ;
#
#
#
#
#             var circle_marker_26494601556792d34bf6e17d7d2cb249 = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2d35293d8db3163a887b472eb9a38b55);
#
#
#         var popup_f09c9d13e75cfe59f18293f49fb8c9e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85232a6dbdf50d325aeba09b8b2635b8 = $(`&lt;div id=&quot;html_85232a6dbdf50d325aeba09b8b2635b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_f09c9d13e75cfe59f18293f49fb8c9e4.setContent(html_85232a6dbdf50d325aeba09b8b2635b8);
#
#
#
#         circle_marker_26494601556792d34bf6e17d7d2cb249.bindPopup(popup_f09c9d13e75cfe59f18293f49fb8c9e4)
#         ;
#
#
#
#
#             var circle_marker_5c01f7aec19b1ea7ad5b8b491884ee87 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null,

# %%
#2027 plotting
columns_to_drop = ['2024', '2025', '2026', '2028']
filtered_2027_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2027_df['Latitude'].mean()
mean_longitude = filtered_2027_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2027_df.iterrows():
    
    amount = row['2027']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2027_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c28ecca950ae95fd5ee76b689ce4834c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c28ecca950ae95fd5ee76b689ce4834c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c28ecca950ae95fd5ee76b689ce4834c = L.map(
#                 &quot;map_c28ecca950ae95fd5ee76b689ce4834c&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2c5bff480713f37f174c89b2d12a1b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2c5bff480713f37f174c89b2d12a1b2.addTo(map_c28ecca950ae95fd5ee76b689ce4834c);
#
#
#             var circle_marker_832e1877b62ec611f5977f465db2e256 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c28ecca950ae95fd5ee76b689ce4834c);
#
#
#         var popup_031bbef99181a87e7b0e527f21315ec6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_55a6713e5177441930097db6728f91e0 = $(`&lt;div id=&quot;html_55a6713e5177441930097db6728f91e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_031bbef99181a87e7b0e527f21315ec6.setContent(html_55a6713e5177441930097db6728f91e0);
#
#
#
#         circle_marker_832e1877b62ec611f5977f465db2e256.bindPopup(popup_031bbef99181a87e7b0e527f21315ec6)
#         ;
#
#
#
#
#             var circle_marker_7c203b44b6dff3a606b7205115e3c07a = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c28ecca950ae95fd5ee76b689ce4834c);
#
#
#         var popup_d24393dc444a5c2aaf4dfd5772f53f78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2794f1b3f4e6646c693bf7cf198b9d2a = $(`&lt;div id=&quot;html_2794f1b3f4e6646c693bf7cf198b9d2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_d24393dc444a5c2aaf4dfd5772f53f78.setContent(html_2794f1b3f4e6646c693bf7cf198b9d2a);
#
#
#
#         circle_marker_7c203b44b6dff3a606b7205115e3c07a.bindPopup(popup_d24393dc444a5c2aaf4dfd5772f53f78)
#         ;
#
#
#
#
#             var circle_marker_64bcee34931ad0e58521a1ec9d3ba3df = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c28ecca950ae95fd5ee76b689ce4834c);
#
#
#         var popup_a6d8cb0352e60e0d985f52ea6b54da29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b18fd57e6d60e9a1e4c0aec532407f9 = $(`&lt;div id=&quot;html_5b18fd57e6d60e9a1e4c0aec532407f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_a6d8cb0352e60e0d985f52ea6b54da29.setContent(html_5b18fd57e6d60e9a1e4c0aec532407f9);
#
#
#
#         circle_marker_64bcee34931ad0e58521a1ec9d3ba3df.bindPopup(popup_a6d8cb0352e60e0d985f52ea6b54da29)
#         ;
#
#
#
#
#             var circle_marker_cc62b6b202a61641b5db1db55fe8f785 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null,

# %%
#2028 plotting
columns_to_drop = ['2024', '2025', '2026', '2027']
filtered_2028_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2028_df['Latitude'].mean()
mean_longitude = filtered_2028_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2028_df.iterrows():
    
    amount = row['2028']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2028_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1177ef32f1969f4d8b0610678a638dbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1177ef32f1969f4d8b0610678a638dbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1177ef32f1969f4d8b0610678a638dbc = L.map(
#                 &quot;map_1177ef32f1969f4d8b0610678a638dbc&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d4d55af4708f522d4c6a954f1e574f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9d4d55af4708f522d4c6a954f1e574f8.addTo(map_1177ef32f1969f4d8b0610678a638dbc);
#
#
#             var circle_marker_feba2b16519df41b89d248ed347cd3e4 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1177ef32f1969f4d8b0610678a638dbc);
#
#
#         var popup_76c614f33865da5170c7b452d78f7636 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09b0a6ac7e4958e319699d7a2a06b734 = $(`&lt;div id=&quot;html_09b0a6ac7e4958e319699d7a2a06b734&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 4.455677493666506e-11&lt;/div&gt;`)[0];
#                 popup_76c614f33865da5170c7b452d78f7636.setContent(html_09b0a6ac7e4958e319699d7a2a06b734);
#
#
#
#         circle_marker_feba2b16519df41b89d248ed347cd3e4.bindPopup(popup_76c614f33865da5170c7b452d78f7636)
#         ;
#
#
#
#
#             var circle_marker_383f0ccc3eabe2df89dc55a8808d47c8 = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1177ef32f1969f4d8b0610678a638dbc);
#
#
#         var popup_e3b21bbbad64fce819af90cc7cea4f56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_524ee4aac0f3245d971cd90f73630fb6 = $(`&lt;div id=&quot;html_524ee4aac0f3245d971cd90f73630fb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_e3b21bbbad64fce819af90cc7cea4f56.setContent(html_524ee4aac0f3245d971cd90f73630fb6);
#
#
#
#         circle_marker_383f0ccc3eabe2df89dc55a8808d47c8.bindPopup(popup_e3b21bbbad64fce819af90cc7cea4f56)
#         ;
#
#
#
#
#             var circle_marker_614af167974357bce86c60c3a6b1c5da = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1177ef32f1969f4d8b0610678a638dbc);
#
#
#         var popup_7aa693b2e9060ecffb7f0731c55e908b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b79332de4ab7af47be6a958d33c462df = $(`&lt;div id=&quot;html_b79332de4ab7af47be6a958d33c462df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_7aa693b2e9060ecffb7f0731c55e908b.setContent(html_b79332de4ab7af47be6a958d33c462df);
#
#
#
#         circle_marker_614af167974357bce86c60c3a6b1c5da.bindPopup(popup_7aa693b2e9060ecffb7f0731c55e908b)
#         ;
#
#
#
#
#             var circle_marker_dd63cf7382388669bc77a01ec517aff8 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashA
