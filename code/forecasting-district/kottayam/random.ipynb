# %%
import folium
import pandas as pd

df=pd.read_csv("./../../../dataset/prediction/RandFr_chumma.csv")
kollam_df = df[df['District'] == "Kottayam"]

# %%
#2024 plotting
columns_to_drop = ['2025', '2026', '2027', '2028']
filtered_2024_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2024_df['Latitude'].mean()
mean_longitude = filtered_2024_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2024_df.iterrows():
    
    amount = row['2024']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2024_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f2d3be2a6a6bdb36b47097777f381ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f2d3be2a6a6bdb36b47097777f381ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f2d3be2a6a6bdb36b47097777f381ec = L.map(
#                 &quot;map_8f2d3be2a6a6bdb36b47097777f381ec&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb7a318609c69dab3b93c481f40b0cb9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bb7a318609c69dab3b93c481f40b0cb9.addTo(map_8f2d3be2a6a6bdb36b47097777f381ec);
#
#
#             var circle_marker_a2af542ffc46716ac1591bd14bd14f2f = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8f2d3be2a6a6bdb36b47097777f381ec);
#
#
#         var popup_b49ec0ac52df40b18e9b95e910e5172b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bdc46832ba9475c474ca08dd9993f7f5 = $(`&lt;div id=&quot;html_bdc46832ba9475c474ca08dd9993f7f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_b49ec0ac52df40b18e9b95e910e5172b.setContent(html_bdc46832ba9475c474ca08dd9993f7f5);
#
#
#
#         circle_marker_a2af542ffc46716ac1591bd14bd14f2f.bindPopup(popup_b49ec0ac52df40b18e9b95e910e5172b)
#         ;
#
#
#
#
#             var circle_marker_fa4a289c4f6de7b524da533fe0148c66 = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8f2d3be2a6a6bdb36b47097777f381ec);
#
#
#         var popup_2604603ee6cd09cda7c264c54685a779 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a5310d81ba9c1d704088d174e0c56342 = $(`&lt;div id=&quot;html_a5310d81ba9c1d704088d174e0c56342&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_2604603ee6cd09cda7c264c54685a779.setContent(html_a5310d81ba9c1d704088d174e0c56342);
#
#
#
#         circle_marker_fa4a289c4f6de7b524da533fe0148c66.bindPopup(popup_2604603ee6cd09cda7c264c54685a779)
#         ;
#
#
#
#
#             var circle_marker_3bd3d9dbfae011ddfeea6209d357083d = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8f2d3be2a6a6bdb36b47097777f381ec);
#
#
#         var popup_601e5ba63da2eea7934a01fbe7ea30d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6fed76d07472688ce9d9bc187751d540 = $(`&lt;div id=&quot;html_6fed76d07472688ce9d9bc187751d540&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_601e5ba63da2eea7934a01fbe7ea30d1.setContent(html_6fed76d07472688ce9d9bc187751d540);
#
#
#
#         circle_marker_3bd3d9dbfae011ddfeea6209d357083d.bindPopup(popup_601e5ba63da2eea7934a01fbe7ea30d1)
#         ;
#
#
#
#
#             var circle_marker_5494dedeb18c2f193be9e2425c47529b = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null,

# %%
#2025 plotting
columns_to_drop = ['2024', '2026', '2027', '2028']
filtered_2025_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2025_df['Latitude'].mean()
mean_longitude = filtered_2025_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2025_df.iterrows():
    
    amount = row['2025']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2025_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0b63c00b78e8a8c097c2386d1184ddb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0b63c00b78e8a8c097c2386d1184ddb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0b63c00b78e8a8c097c2386d1184ddb = L.map(
#                 &quot;map_c0b63c00b78e8a8c097c2386d1184ddb&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e786318d83e413fe54308831a95a49f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e786318d83e413fe54308831a95a49f2.addTo(map_c0b63c00b78e8a8c097c2386d1184ddb);
#
#
#             var circle_marker_fe41eef7dbf059033900d2672b1b78fe = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0b63c00b78e8a8c097c2386d1184ddb);
#
#
#         var popup_2eba3f8b6b13362b737fd50794d5510f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b760cb8d79ffaa61070ae8b1ce2595e4 = $(`&lt;div id=&quot;html_b760cb8d79ffaa61070ae8b1ce2595e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_2eba3f8b6b13362b737fd50794d5510f.setContent(html_b760cb8d79ffaa61070ae8b1ce2595e4);
#
#
#
#         circle_marker_fe41eef7dbf059033900d2672b1b78fe.bindPopup(popup_2eba3f8b6b13362b737fd50794d5510f)
#         ;
#
#
#
#
#             var circle_marker_7ac2a042c1b6d9676eb7b73feec692bd = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0b63c00b78e8a8c097c2386d1184ddb);
#
#
#         var popup_98978fd1bd23e13d8c0d705bdfa620d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f8caf506ef6b4661e03a8669303de25a = $(`&lt;div id=&quot;html_f8caf506ef6b4661e03a8669303de25a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_98978fd1bd23e13d8c0d705bdfa620d0.setContent(html_f8caf506ef6b4661e03a8669303de25a);
#
#
#
#         circle_marker_7ac2a042c1b6d9676eb7b73feec692bd.bindPopup(popup_98978fd1bd23e13d8c0d705bdfa620d0)
#         ;
#
#
#
#
#             var circle_marker_ac454e5b6eb478e8589ce83e6e4b5f18 = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0b63c00b78e8a8c097c2386d1184ddb);
#
#
#         var popup_31ab5adb2b4c929f6d5d6304507cd146 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c8f7b35d10ab2f14eb143f4f9b31d45 = $(`&lt;div id=&quot;html_7c8f7b35d10ab2f14eb143f4f9b31d45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_31ab5adb2b4c929f6d5d6304507cd146.setContent(html_7c8f7b35d10ab2f14eb143f4f9b31d45);
#
#
#
#         circle_marker_ac454e5b6eb478e8589ce83e6e4b5f18.bindPopup(popup_31ab5adb2b4c929f6d5d6304507cd146)
#         ;
#
#
#
#
#             var circle_marker_33a0b6657ee518260cb117a4625c0623 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null,

# %%
#2026 plotting
columns_to_drop = ['2024', '2025', '2027', '2028']
filtered_2026_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2026_df['Latitude'].mean()
mean_longitude = filtered_2026_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2026_df.iterrows():
    
    amount = row['2026']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2026_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9ee0dada08fb689936aee6c09a021a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9ee0dada08fb689936aee6c09a021a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9ee0dada08fb689936aee6c09a021a2 = L.map(
#                 &quot;map_a9ee0dada08fb689936aee6c09a021a2&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12c230ccde8a5398e1c81d48fadc68e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_12c230ccde8a5398e1c81d48fadc68e5.addTo(map_a9ee0dada08fb689936aee6c09a021a2);
#
#
#             var circle_marker_cb385fb553f9b8372e99d061bb50c831 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a9ee0dada08fb689936aee6c09a021a2);
#
#
#         var popup_fd21c6dd7b4521aa38c8c8136b714264 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e4f06f2a70c1269b0deac4649614595 = $(`&lt;div id=&quot;html_8e4f06f2a70c1269b0deac4649614595&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_fd21c6dd7b4521aa38c8c8136b714264.setContent(html_8e4f06f2a70c1269b0deac4649614595);
#
#
#
#         circle_marker_cb385fb553f9b8372e99d061bb50c831.bindPopup(popup_fd21c6dd7b4521aa38c8c8136b714264)
#         ;
#
#
#
#
#             var circle_marker_6617b03a4f1f4ed0506d0d92f9fea6a4 = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a9ee0dada08fb689936aee6c09a021a2);
#
#
#         var popup_f22d392bf5785d4cf6232a2c14c5c9aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b115555370ee79259186d67ed3ff8bac = $(`&lt;div id=&quot;html_b115555370ee79259186d67ed3ff8bac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_f22d392bf5785d4cf6232a2c14c5c9aa.setContent(html_b115555370ee79259186d67ed3ff8bac);
#
#
#
#         circle_marker_6617b03a4f1f4ed0506d0d92f9fea6a4.bindPopup(popup_f22d392bf5785d4cf6232a2c14c5c9aa)
#         ;
#
#
#
#
#             var circle_marker_44895aa7827405ebcd39177021db5313 = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a9ee0dada08fb689936aee6c09a021a2);
#
#
#         var popup_c5700aaf1519e35b60138490f7cb8d0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9cf5a94e2891fe6f4a037e063aa90689 = $(`&lt;div id=&quot;html_9cf5a94e2891fe6f4a037e063aa90689&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_c5700aaf1519e35b60138490f7cb8d0e.setContent(html_9cf5a94e2891fe6f4a037e063aa90689);
#
#
#
#         circle_marker_44895aa7827405ebcd39177021db5313.bindPopup(popup_c5700aaf1519e35b60138490f7cb8d0e)
#         ;
#
#
#
#
#             var circle_marker_fcf77585464eaaebc805bcd80a7811b6 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null,

# %%
#2027 plotting
columns_to_drop = ['2024', '2025', '2026', '2028']
filtered_2027_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2027_df['Latitude'].mean()
mean_longitude = filtered_2027_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2027_df.iterrows():
    
    amount = row['2027']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2027_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c93fb3b47258fa2910d8d443cad013aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c93fb3b47258fa2910d8d443cad013aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c93fb3b47258fa2910d8d443cad013aa = L.map(
#                 &quot;map_c93fb3b47258fa2910d8d443cad013aa&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0083ef9cc8490076526e8230255ab60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d0083ef9cc8490076526e8230255ab60.addTo(map_c93fb3b47258fa2910d8d443cad013aa);
#
#
#             var circle_marker_b7adf8006de2094b2974cb060828a8c1 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c93fb3b47258fa2910d8d443cad013aa);
#
#
#         var popup_3347d60e97b9aeb337ddf4d9c3d5c669 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9cf6743d60ce15e6664d1c24440787d7 = $(`&lt;div id=&quot;html_9cf6743d60ce15e6664d1c24440787d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_3347d60e97b9aeb337ddf4d9c3d5c669.setContent(html_9cf6743d60ce15e6664d1c24440787d7);
#
#
#
#         circle_marker_b7adf8006de2094b2974cb060828a8c1.bindPopup(popup_3347d60e97b9aeb337ddf4d9c3d5c669)
#         ;
#
#
#
#
#             var circle_marker_4fce8cb6ccce79680ea4bf11f851051b = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c93fb3b47258fa2910d8d443cad013aa);
#
#
#         var popup_03ca8ea35de2e3e26094d24b1b1feb7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3c0ce365f0fad5d33f6e544c53f3271 = $(`&lt;div id=&quot;html_d3c0ce365f0fad5d33f6e544c53f3271&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_03ca8ea35de2e3e26094d24b1b1feb7a.setContent(html_d3c0ce365f0fad5d33f6e544c53f3271);
#
#
#
#         circle_marker_4fce8cb6ccce79680ea4bf11f851051b.bindPopup(popup_03ca8ea35de2e3e26094d24b1b1feb7a)
#         ;
#
#
#
#
#             var circle_marker_78db489cb6fdafbfa2904928a3a7b903 = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c93fb3b47258fa2910d8d443cad013aa);
#
#
#         var popup_70525d006cd8d64b29d1369db1f50540 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b0277f01b2b6449123c6d47ad61082b = $(`&lt;div id=&quot;html_8b0277f01b2b6449123c6d47ad61082b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_70525d006cd8d64b29d1369db1f50540.setContent(html_8b0277f01b2b6449123c6d47ad61082b);
#
#
#
#         circle_marker_78db489cb6fdafbfa2904928a3a7b903.bindPopup(popup_70525d006cd8d64b29d1369db1f50540)
#         ;
#
#
#
#
#             var circle_marker_9ad8e0ab4ae3cc1ffdd3fe117074b6c9 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null,

# %%
#2028 plotting
columns_to_drop = ['2024', '2025', '2026', '2027']
filtered_2028_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2028_df['Latitude'].mean()
mean_longitude = filtered_2028_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2028_df.iterrows():
    
    amount = row['2028']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='maroon',  
                        fill=True, 
                        fill_color='maroon',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2028_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e21b5e99b48c4b7e3326ab20f96802f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e21b5e99b48c4b7e3326ab20f96802f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e21b5e99b48c4b7e3326ab20f96802f2 = L.map(
#                 &quot;map_e21b5e99b48c4b7e3326ab20f96802f2&quot;,
#                 {
#                     center: [9.58942417070376, 76.57063259998294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d50c604995fabbe56c197a403c1ca1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4d50c604995fabbe56c197a403c1ca1e.addTo(map_e21b5e99b48c4b7e3326ab20f96802f2);
#
#
#             var circle_marker_a9a7e4c6eb9acb2a7c58effe04650c0b = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e21b5e99b48c4b7e3326ab20f96802f2);
#
#
#         var popup_ad3724e0ce3c50ef3f2ad1587ad64dfe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd1bdc0220be3d768d05ed41b094061e = $(`&lt;div id=&quot;html_cd1bdc0220be3d768d05ed41b094061e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_ad3724e0ce3c50ef3f2ad1587ad64dfe.setContent(html_cd1bdc0220be3d768d05ed41b094061e);
#
#
#
#         circle_marker_a9a7e4c6eb9acb2a7c58effe04650c0b.bindPopup(popup_ad3724e0ce3c50ef3f2ad1587ad64dfe)
#         ;
#
#
#
#
#             var circle_marker_83d3f03a3e42832c5b122cc942452ec0 = L.circleMarker(
#                 [9.592533289090907, 76.58230555090908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e21b5e99b48c4b7e3326ab20f96802f2);
#
#
#         var popup_99e9ed848db0aae4b20c48481eae0038 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23ffbb18cf18d63fc443214aea6fe8e1 = $(`&lt;div id=&quot;html_23ffbb18cf18d63fc443214aea6fe8e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_99e9ed848db0aae4b20c48481eae0038.setContent(html_23ffbb18cf18d63fc443214aea6fe8e1);
#
#
#
#         circle_marker_83d3f03a3e42832c5b122cc942452ec0.bindPopup(popup_99e9ed848db0aae4b20c48481eae0038)
#         ;
#
#
#
#
#             var circle_marker_5b7f9e1754ec0c51e7ea32bce837db44 = L.circleMarker(
#                 [9.581621149411763, 76.63691744941177],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;maroon&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e21b5e99b48c4b7e3326ab20f96802f2);
#
#
#         var popup_9955a2ba697848a3699203cde7b1eb5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50efce912c290f845825f2a72145b2b7 = $(`&lt;div id=&quot;html_50efce912c290f845825f2a72145b2b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_9955a2ba697848a3699203cde7b1eb5c.setContent(html_50efce912c290f845825f2a72145b2b7);
#
#
#
#         circle_marker_5b7f9e1754ec0c51e7ea32bce837db44.bindPopup(popup_9955a2ba697848a3699203cde7b1eb5c)
#         ;
#
#
#
#
#             var circle_marker_5718b156ff4970ad26227826d58d3762 = L.circleMarker(
#                 [9.54856711111111, 76.52230786666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;maroon&quot;, &quot;dashArray&quot;: null,
