# %%
import folium
import pandas as pd

df=pd.read_csv("./../../../dataset/prediction/RandFr_chumma.csv")
kollam_df = df[df['District'] == "Kollam"]

# %%
#2024 plotting
columns_to_drop = ['2025', '2026', '2027', '2028']
filtered_2024_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2024_df['Latitude'].mean()
mean_longitude = filtered_2024_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2024_df.iterrows():
    
    amount = row['2024']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='magenta',  
                        fill=True, 
                        fill_color='magenta',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2024_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85743afa256a32951614082e151a7c79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85743afa256a32951614082e151a7c79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85743afa256a32951614082e151a7c79 = L.map(
#                 &quot;map_85743afa256a32951614082e151a7c79&quot;,
#                 {
#                     center: [8.941194573785662, 76.6619326000351],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48b334348aa9bb8adb887e100614a1f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_48b334348aa9bb8adb887e100614a1f5.addTo(map_85743afa256a32951614082e151a7c79);
#
#
#             var circle_marker_4a2ddb6702b3056b8c6304d2b68bd74e = L.circleMarker(
#                 [9.043139252830189, 76.7161006773585],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_85743afa256a32951614082e151a7c79);
#
#
#         var popup_52f2f3c0e216530e65b7c033439523b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d392b7f27324fc63b9c2a1cf7d0adcbf = $(`&lt;div id=&quot;html_d392b7f27324fc63b9c2a1cf7d0adcbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 1299973.81&lt;/div&gt;`)[0];
#                 popup_52f2f3c0e216530e65b7c033439523b5.setContent(html_d392b7f27324fc63b9c2a1cf7d0adcbf);
#
#
#
#         circle_marker_4a2ddb6702b3056b8c6304d2b68bd74e.bindPopup(popup_52f2f3c0e216530e65b7c033439523b5)
#         ;
#
#
#
#
#             var circle_marker_d9b32c9f1e233e45cf03bdb8960b5412 = L.circleMarker(
#                 [9.04378430952381, 76.78092363809523],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_85743afa256a32951614082e151a7c79);
#
#
#         var popup_f3bc117556bb983ec24020329db02af6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4828987682b7f5270d1ae2cb8879b807 = $(`&lt;div id=&quot;html_4828987682b7f5270d1ae2cb8879b807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_f3bc117556bb983ec24020329db02af6.setContent(html_4828987682b7f5270d1ae2cb8879b807);
#
#
#
#         circle_marker_d9b32c9f1e233e45cf03bdb8960b5412.bindPopup(popup_f3bc117556bb983ec24020329db02af6)
#         ;
#
#
#
#
#             var circle_marker_826433f5d64ee150a773fe1cf1fb3995 = L.circleMarker(
#                 [8.928226436363635, 76.54678488181818],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_85743afa256a32951614082e151a7c79);
#
#
#         var popup_a8c978d8facbd296af8acc55f0f63e1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3fa14024f07c43c321f5245042730dec = $(`&lt;div id=&quot;html_3fa14024f07c43c321f5245042730dec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 2716810.23&lt;/div&gt;`)[0];
#                 popup_a8c978d8facbd296af8acc55f0f63e1e.setContent(html_3fa14024f07c43c321f5245042730dec);
#
#
#
#         circle_marker_826433f5d64ee150a773fe1cf1fb3995.bindPopup(popup_a8c978d8facbd296af8acc55f0f63e1e)
#         ;
#
#
#
#
#             var circle_marker_a29c4e3cf56d6e07bdd7245594059474 = L.circleMarker(
#                 [9.008392784545457, 76.65603456545455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;da

# %%
#2025 plotting
columns_to_drop = ['2024', '2026', '2027', '2028']
filtered_2025_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2025_df['Latitude'].mean()
mean_longitude = filtered_2025_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2025_df.iterrows():
    
    amount = row['2025']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='magenta',  
                        fill=True, 
                        fill_color='magenta',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2025_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52e12b2c5e56c8305aa12caf1bb60ac9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52e12b2c5e56c8305aa12caf1bb60ac9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52e12b2c5e56c8305aa12caf1bb60ac9 = L.map(
#                 &quot;map_52e12b2c5e56c8305aa12caf1bb60ac9&quot;,
#                 {
#                     center: [8.941194573785662, 76.6619326000351],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2deca8965e5d48cf480031cf14c35481 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2deca8965e5d48cf480031cf14c35481.addTo(map_52e12b2c5e56c8305aa12caf1bb60ac9);
#
#
#             var circle_marker_e72103387ce92fc64972bec421eff5ba = L.circleMarker(
#                 [9.043139252830189, 76.7161006773585],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_52e12b2c5e56c8305aa12caf1bb60ac9);
#
#
#         var popup_529b099dc9ec8f2cded4cd87ba3b9b2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c249e06c311a4311d93631ba3e00e41 = $(`&lt;div id=&quot;html_0c249e06c311a4311d93631ba3e00e41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 1297591.36&lt;/div&gt;`)[0];
#                 popup_529b099dc9ec8f2cded4cd87ba3b9b2a.setContent(html_0c249e06c311a4311d93631ba3e00e41);
#
#
#
#         circle_marker_e72103387ce92fc64972bec421eff5ba.bindPopup(popup_529b099dc9ec8f2cded4cd87ba3b9b2a)
#         ;
#
#
#
#
#             var circle_marker_9d7a0d7d6e0f59592a065302968fdf2f = L.circleMarker(
#                 [9.04378430952381, 76.78092363809523],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_52e12b2c5e56c8305aa12caf1bb60ac9);
#
#
#         var popup_1d74081047814d382620471ab46017e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a58283e83a49b035874bc1e33870e0f7 = $(`&lt;div id=&quot;html_a58283e83a49b035874bc1e33870e0f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_1d74081047814d382620471ab46017e1.setContent(html_a58283e83a49b035874bc1e33870e0f7);
#
#
#
#         circle_marker_9d7a0d7d6e0f59592a065302968fdf2f.bindPopup(popup_1d74081047814d382620471ab46017e1)
#         ;
#
#
#
#
#             var circle_marker_f07543e183622cec4a105d36196c7705 = L.circleMarker(
#                 [8.928226436363635, 76.54678488181818],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_52e12b2c5e56c8305aa12caf1bb60ac9);
#
#
#         var popup_21b07e9408165b6d874b529432b0e701 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6dc163062c1a92e57641f2ff88b8f55d = $(`&lt;div id=&quot;html_6dc163062c1a92e57641f2ff88b8f55d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 2711867.36&lt;/div&gt;`)[0];
#                 popup_21b07e9408165b6d874b529432b0e701.setContent(html_6dc163062c1a92e57641f2ff88b8f55d);
#
#
#
#         circle_marker_f07543e183622cec4a105d36196c7705.bindPopup(popup_21b07e9408165b6d874b529432b0e701)
#         ;
#
#
#
#
#             var circle_marker_07ec20897e38ee846076fbc84a56a133 = L.circleMarker(
#                 [9.008392784545457, 76.65603456545455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;da

# %%
#2026 plotting
columns_to_drop = ['2024', '2025', '2027', '2028']
filtered_2026_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2026_df['Latitude'].mean()
mean_longitude = filtered_2026_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2026_df.iterrows():
    
    amount = row['2026']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='magenta',  
                        fill=True, 
                        fill_color='magenta',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2026_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c59996f6dfbb3540249de862513f8f34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c59996f6dfbb3540249de862513f8f34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c59996f6dfbb3540249de862513f8f34 = L.map(
#                 &quot;map_c59996f6dfbb3540249de862513f8f34&quot;,
#                 {
#                     center: [8.941194573785662, 76.6619326000351],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e4ec77c1f946c861edcfd9c478e0a21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8e4ec77c1f946c861edcfd9c478e0a21.addTo(map_c59996f6dfbb3540249de862513f8f34);
#
#
#             var circle_marker_6696e7338853fb0d67f9670b5998a2f4 = L.circleMarker(
#                 [9.043139252830189, 76.7161006773585],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c59996f6dfbb3540249de862513f8f34);
#
#
#         var popup_dd21d7dd47d255e12b451e101f09732f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a103816afc982338b82fdaeca5389cc6 = $(`&lt;div id=&quot;html_a103816afc982338b82fdaeca5389cc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 1298424.77&lt;/div&gt;`)[0];
#                 popup_dd21d7dd47d255e12b451e101f09732f.setContent(html_a103816afc982338b82fdaeca5389cc6);
#
#
#
#         circle_marker_6696e7338853fb0d67f9670b5998a2f4.bindPopup(popup_dd21d7dd47d255e12b451e101f09732f)
#         ;
#
#
#
#
#             var circle_marker_6ef277322ad4f1293d2ad9acaeff5b5c = L.circleMarker(
#                 [9.04378430952381, 76.78092363809523],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c59996f6dfbb3540249de862513f8f34);
#
#
#         var popup_8b5f1bb3d6266c4f42eec0ebcee747f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19df12cd7292773cfd2313d70886bf1e = $(`&lt;div id=&quot;html_19df12cd7292773cfd2313d70886bf1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_8b5f1bb3d6266c4f42eec0ebcee747f7.setContent(html_19df12cd7292773cfd2313d70886bf1e);
#
#
#
#         circle_marker_6ef277322ad4f1293d2ad9acaeff5b5c.bindPopup(popup_8b5f1bb3d6266c4f42eec0ebcee747f7)
#         ;
#
#
#
#
#             var circle_marker_c1b5db4a992d0e9d40fa47bf3a1db1c2 = L.circleMarker(
#                 [8.928226436363635, 76.54678488181818],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c59996f6dfbb3540249de862513f8f34);
#
#
#         var popup_4a3f740092f59bd4217bc5601533b780 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_310e3756624b56fe0df44fa80a50d36f = $(`&lt;div id=&quot;html_310e3756624b56fe0df44fa80a50d36f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 2712309.65&lt;/div&gt;`)[0];
#                 popup_4a3f740092f59bd4217bc5601533b780.setContent(html_310e3756624b56fe0df44fa80a50d36f);
#
#
#
#         circle_marker_c1b5db4a992d0e9d40fa47bf3a1db1c2.bindPopup(popup_4a3f740092f59bd4217bc5601533b780)
#         ;
#
#
#
#
#             var circle_marker_4232e278a0389d3e97dbddc2fcd613bf = L.circleMarker(
#                 [9.008392784545457, 76.65603456545455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;da

# %%
#2027 plotting
columns_to_drop = ['2024', '2025', '2026', '2028']
filtered_2027_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2027_df['Latitude'].mean()
mean_longitude = filtered_2027_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2027_df.iterrows():
    
    amount = row['2027']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='magenta',  
                        fill=True, 
                        fill_color='magenta',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2027_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_696cc921dea893a4f2220b7be2e125c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_696cc921dea893a4f2220b7be2e125c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_696cc921dea893a4f2220b7be2e125c7 = L.map(
#                 &quot;map_696cc921dea893a4f2220b7be2e125c7&quot;,
#                 {
#                     center: [8.941194573785662, 76.6619326000351],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9e7803f32d647d8328bdb621fa19e0d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b9e7803f32d647d8328bdb621fa19e0d.addTo(map_696cc921dea893a4f2220b7be2e125c7);
#
#
#             var circle_marker_dcb9fb51034504bb2185fae452b41c19 = L.circleMarker(
#                 [9.043139252830189, 76.7161006773585],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_696cc921dea893a4f2220b7be2e125c7);
#
#
#         var popup_43e6038cb853371ad77ca76f4004bbba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_764947f93979f4b41e2983a073f16132 = $(`&lt;div id=&quot;html_764947f93979f4b41e2983a073f16132&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 1296183.09&lt;/div&gt;`)[0];
#                 popup_43e6038cb853371ad77ca76f4004bbba.setContent(html_764947f93979f4b41e2983a073f16132);
#
#
#
#         circle_marker_dcb9fb51034504bb2185fae452b41c19.bindPopup(popup_43e6038cb853371ad77ca76f4004bbba)
#         ;
#
#
#
#
#             var circle_marker_026ec9f386571fd647a974b478c066e2 = L.circleMarker(
#                 [9.04378430952381, 76.78092363809523],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_696cc921dea893a4f2220b7be2e125c7);
#
#
#         var popup_38b5e085da0288d223d3279c2bc51663 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1a05f4e25a2ed351b0ec2d76bf0bb58 = $(`&lt;div id=&quot;html_b1a05f4e25a2ed351b0ec2d76bf0bb58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_38b5e085da0288d223d3279c2bc51663.setContent(html_b1a05f4e25a2ed351b0ec2d76bf0bb58);
#
#
#
#         circle_marker_026ec9f386571fd647a974b478c066e2.bindPopup(popup_38b5e085da0288d223d3279c2bc51663)
#         ;
#
#
#
#
#             var circle_marker_342d5b8548ede864611c8005675a42ae = L.circleMarker(
#                 [8.928226436363635, 76.54678488181818],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_696cc921dea893a4f2220b7be2e125c7);
#
#
#         var popup_8e79dc7a061eaa7a3c16b851e09fb801 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b0593491a7d910462471b8cd7f94402 = $(`&lt;div id=&quot;html_7b0593491a7d910462471b8cd7f94402&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 2708638.0&lt;/div&gt;`)[0];
#                 popup_8e79dc7a061eaa7a3c16b851e09fb801.setContent(html_7b0593491a7d910462471b8cd7f94402);
#
#
#
#         circle_marker_342d5b8548ede864611c8005675a42ae.bindPopup(popup_8e79dc7a061eaa7a3c16b851e09fb801)
#         ;
#
#
#
#
#             var circle_marker_f76a62acdba6ada230aa9acb6dcf562c = L.circleMarker(
#                 [9.008392784545457, 76.65603456545455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;das

# %%
#2028 plotting
columns_to_drop = ['2024', '2025', '2026', '2027']
filtered_2028_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2028_df['Latitude'].mean()
mean_longitude = filtered_2028_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2028_df.iterrows():
    
    amount = row['2028']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='magenta',  
                        fill=True, 
                        fill_color='magenta',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2028_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96a9ef516d9207a3b3fc9d8c58ff78c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96a9ef516d9207a3b3fc9d8c58ff78c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96a9ef516d9207a3b3fc9d8c58ff78c1 = L.map(
#                 &quot;map_96a9ef516d9207a3b3fc9d8c58ff78c1&quot;,
#                 {
#                     center: [8.941194573785662, 76.6619326000351],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b67cb3e8e7975debe68048a87e680150 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b67cb3e8e7975debe68048a87e680150.addTo(map_96a9ef516d9207a3b3fc9d8c58ff78c1);
#
#
#             var circle_marker_72da85d4ac7126a479548e01f4da3b57 = L.circleMarker(
#                 [9.043139252830189, 76.7161006773585],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_96a9ef516d9207a3b3fc9d8c58ff78c1);
#
#
#         var popup_4b93954d88499fe533d9d5b37848ef7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58746d39d127733cfac8d043f34b31ca = $(`&lt;div id=&quot;html_58746d39d127733cfac8d043f34b31ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 1298239.5&lt;/div&gt;`)[0];
#                 popup_4b93954d88499fe533d9d5b37848ef7b.setContent(html_58746d39d127733cfac8d043f34b31ca);
#
#
#
#         circle_marker_72da85d4ac7126a479548e01f4da3b57.bindPopup(popup_4b93954d88499fe533d9d5b37848ef7b)
#         ;
#
#
#
#
#             var circle_marker_948e0ef6529699cb87e2c79831c35a93 = L.circleMarker(
#                 [9.04378430952381, 76.78092363809523],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_96a9ef516d9207a3b3fc9d8c58ff78c1);
#
#
#         var popup_840bd2e7ce63b1ee14d1d9593c2d4ef9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94cef803cb7763c16e07a61bdf1eed51 = $(`&lt;div id=&quot;html_94cef803cb7763c16e07a61bdf1eed51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 0.0&lt;/div&gt;`)[0];
#                 popup_840bd2e7ce63b1ee14d1d9593c2d4ef9.setContent(html_94cef803cb7763c16e07a61bdf1eed51);
#
#
#
#         circle_marker_948e0ef6529699cb87e2c79831c35a93.bindPopup(popup_840bd2e7ce63b1ee14d1d9593c2d4ef9)
#         ;
#
#
#
#
#             var circle_marker_3b56fff31cc52e27879d0340f0af500b = L.circleMarker(
#                 [8.928226436363635, 76.54678488181818],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_96a9ef516d9207a3b3fc9d8c58ff78c1);
#
#
#         var popup_423e39859899ed6e59c71337af54aa80 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_270cdc20abd33b2e525fc9307023874d = $(`&lt;div id=&quot;html_270cdc20abd33b2e525fc9307023874d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0, Amount: 2719584.91&lt;/div&gt;`)[0];
#                 popup_423e39859899ed6e59c71337af54aa80.setContent(html_270cdc20abd33b2e525fc9307023874d);
#
#
#
#         circle_marker_3b56fff31cc52e27879d0340f0af500b.bindPopup(popup_423e39859899ed6e59c71337af54aa80)
#         ;
#
#
#
#
#             var circle_marker_d8ace25c637c5de9aea0f60070a6997d = L.circleMarker(
#                 [9.008392784545457, 76.65603456545455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;das
