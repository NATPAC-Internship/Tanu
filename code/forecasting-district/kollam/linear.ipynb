# %%
import folium
import pandas as pd

df=pd.read_csv("./../../../dataset/prediction/Linear_chumma.csv")
kollam_df = df[df['District'] == "Kollam"]

# %%
#2024 plotting
columns_to_drop = ['2025', '2026', '2027', '2028']
filtered_2024_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2024_df['Latitude'].mean()
mean_longitude = filtered_2024_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2024_df.iterrows():
    
    amount = row['2024']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='magenta',  
                        fill=True, 
                        fill_color='magenta',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2024_map_.html'
mymap.save(filename)
mymap

# %%
#2025 plotting
columns_to_drop = ['2024', '2026', '2027', '2028']
filtered_2025_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2025_df['Latitude'].mean()
mean_longitude = filtered_2025_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2025_df.iterrows():
    
    amount = row['2025']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='magenta',  
                        fill=True, 
                        fill_color='magenta',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2025_map_.html'
mymap.save(filename)
mymap

# %%
#2026 plotting
columns_to_drop = ['2024', '2025', '2027', '2028']
filtered_2026_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2026_df['Latitude'].mean()
mean_longitude = filtered_2026_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2026_df.iterrows():
    
    amount = row['2026']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='magenta',  
                        fill=True, 
                        fill_color='magenta',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2026_map_.html'
mymap.save(filename)
mymap

# %%
#2027 plotting
columns_to_drop = ['2024', '2025', '2026', '2028']
filtered_2027_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2027_df['Latitude'].mean()
mean_longitude = filtered_2027_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2027_df.iterrows():
    
    amount = row['2027']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='magenta',  
                        fill=True, 
                        fill_color='magenta',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2027_map_.html'
mymap.save(filename)
mymap

# %%
#2028 plotting
columns_to_drop = ['2024', '2025', '2026', '2027']
filtered_2028_df = kollam_df.drop(columns=columns_to_drop, axis=1)

mean_latitude = filtered_2028_df['Latitude'].mean()
mean_longitude = filtered_2028_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5


for index, row in filtered_2028_df.iterrows():
    
    amount = row['2028']  
    circle_radius = get_circle_radius(amount)
    
  
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='magenta',  
                        fill=True, 
                        fill_color='magenta',  
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

filename = f'2028_map_.html'
mymap.save(filename)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
